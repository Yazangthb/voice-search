# %%
import torch
import torchaudio

print(torch.__version__)
print(torchaudio.__version__)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# 2.3.1
# 2.3.1
# cuda

# %% [markdown]
# ## Overview
#
# The process of alignment looks like the following.
#
# 1. Estimate the frame-wise label probability from audio waveform
# 2. Generate the trellis matrix which represents the probability of
#    labels aligned at time step.
# 3. Find the most likely path from the trellis matrix.
#
# In this example, we use ``torchaudio``\ ’s ``Wav2Vec2`` model for
# acoustic feature extraction.

# %% [markdown]
# ## Preparation
#
# First we import the necessary packages, and fetch data that we work on.

# %%
from dataclasses import dataclass

import IPython
import matplotlib.pyplot as plt

torch.random.manual_seed(0)

# SPEECH_FILE = torchaudio.utils.download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")
SPEECH_FILE="E:/project_summer/welcome.mp3"

# %%
pip install soundfile
# Out:
# Requirement already satisfied: soundfile in e:\anacon2\envs\mypyt\lib\site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in e:\anacon2\envs\mypyt\lib\site-packages (from soundfile) (1.16.0)
# Requirement already satisfied: pycparser in e:\anacon2\envs\mypyt\lib\site-packages (from cffi>=1.0->soundfile) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Generate frame-wise label probability
#
# The first step is to generate the label class porbability of each audio
# frame. We can use a Wav2Vec2 model that is trained for ASR. Here we use
# :py:func:`torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H`.
#
# ``torchaudio`` provides easy access to pretrained models with associated
# labels.

# %%
bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
model = bundle.get_model().to(device)
labels = bundle.get_labels()
with torch.inference_mode():
    waveform, _ = torchaudio.load(SPEECH_FILE,format='mp3')
    emissions, _ = model(waveform.to(device))
    emissions = torch.log_softmax(emissions, dim=-1)

emission = emissions[0].cpu().detach()

print(labels)
# Out:
# ('-', '|', 'E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'D', 'L', 'U', 'M', 'W', 'C', 'F', 'G', 'Y', 'P', 'B', 'V', 'K', "'", 'X', 'J', 'Q', 'Z')
# e:\anacon2\envs\mypyt\Lib\site-packages\torchaudio\models\wav2vec2\components.py:305: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(

# %% [markdown]
# ### Visualization

# %%
def plot():
    fig, ax = plt.subplots()
    img = ax.imshow(emission.T)
    ax.set_title("Frame-wise class probability")
    ax.set_xlabel("Time")
    ax.set_ylabel("Labels")
    fig.colorbar(img, ax=ax, shrink=0.6, location="bottom")
    fig.tight_layout()


plot()

# %% [markdown]
# ## Generate alignment probability (trellis)
#
# From the emission matrix, next we generate the trellis which represents
# the probability of transcript labels occur at each time frame.
#
# Trellis is 2D matrix with time axis and label axis. The label axis
# represents the transcript that we are aligning. In the following, we use
# $t$ to denote the index in time axis and $j$ to denote the
# index in label axis. $c_j$ represents the label at label index
# $j$.
#
# To generate, the probability of time step $t+1$, we look at the
# trellis from time step $t$ and emission at time step $t+1$.
# There are two path to reach to time step $t+1$ with label
# $c_{j+1}$. The first one is the case where the label was
# $c_{j+1}$ at $t$ and there was no label change from
# $t$ to $t+1$. The other case is where the label was
# $c_j$ at $t$ and it transitioned to the next label
# $c_{j+1}$ at $t+1$.
#
# The follwoing diagram illustrates this transition.
#
# <img src="https://download.pytorch.org/torchaudio/tutorial-assets/ctc-forward.png">
#
# Since we are looking for the most likely transitions, we take the more
# likely path for the value of $k_{(t+1, j+1)}$, that is
#
# $k_{(t+1, j+1)} = max( k_{(t, j)} p(t+1, c_{j+1}), k_{(t, j+1)} p(t+1, repeat) )$
#
# where $k$ represents is trellis matrix, and $p(t, c_j)$
# represents the probability of label $c_j$ at time step $t$.
# $repeat$ represents the blank token from CTC formulation. (For the
# detail of CTC algorithm, please refer to the *Sequence Modeling with CTC*
# [[distill.pub](https://distill.pub/2017/ctc/)_])

# %%
# We enclose the transcript with space tokens, which represent SOS and EOS.
transcript = "|A|BOTTLE|OF|WATER|H|H|"
dictionary = {c: i for i, c in enumerate(labels)}

tokens = [dictionary[c] for c in transcript]
print(list(zip(transcript, tokens)))


def get_trellis(emission, tokens, blank_id=0):
    num_frame = emission.size(0)
    num_tokens = len(tokens)

    trellis = torch.zeros((num_frame, num_tokens))
    trellis[1:, 0] = torch.cumsum(emission[1:, blank_id], 0)
    trellis[0, 1:] = -float("inf")
    trellis[-num_tokens + 1 :, 0] = float("inf")

    for t in range(num_frame - 1):
        trellis[t + 1, 1:] = torch.maximum(
            # Score for staying at the same token
            trellis[t, 1:] + emission[t, blank_id],
            # Score for changing to the next token
            trellis[t, :-1] + emission[t, tokens[1:]],
        )
    return trellis


trellis = get_trellis(emission, tokens)
# Out:
# [('|', 1), ('A', 4), ('|', 1), ('B', 21), ('O', 5), ('T', 3), ('T', 3), ('L', 12), ('E', 2), ('|', 1), ('O', 5), ('F', 17), ('|', 1), ('W', 15), ('A', 4), ('T', 3), ('E', 2), ('R', 10), ('|', 1), ('H', 8), ('|', 1), ('H', 8), ('|', 1)]

# %% [markdown]
# ### Visualization

# %%
def plot():
    fig, ax = plt.subplots()
    img = ax.imshow(trellis.T, origin="lower")
    ax.annotate("- Inf", (trellis.size(1) / 5, trellis.size(1) / 1.5))
    ax.annotate("+ Inf", (trellis.size(0) - trellis.size(1) / 5, trellis.size(1) / 3))
    fig.colorbar(img, ax=ax, shrink=0.6, location="bottom")
    fig.tight_layout()


plot()

# %% [markdown]
# In the above visualization, we can see that there is a trace of high
# probability crossing the matrix diagonally.

# %% [markdown]
# ## Find the most likely path (backtracking)
#
# Once the trellis is generated, we will traverse it following the
# elements with high probability.
#
# We will start from the last label index with the time step of highest
# probability, then, we traverse back in time, picking stay
# ($c_j \rightarrow c_j$) or transition
# ($c_j \rightarrow c_{j+1}$), based on the post-transition
# probability $k_{t, j} p(t+1, c_{j+1})$ or
# $k_{t, j+1} p(t+1, repeat)$.
#
# Transition is done once the label reaches the beginning.
#
# The trellis matrix is used for path-finding, but for the final
# probability of each segment, we take the frame-wise probability from
# emission matrix.

# %%
@dataclass
class Point:
    token_index: int
    time_index: int
    score: float


def backtrack(trellis, emission, tokens, blank_id=0):
    t, j = trellis.size(0) - 1, trellis.size(1) - 1

    path = [Point(j, t, emission[t, blank_id].exp().item())]
    while j > 0:
        # Should not happen but just in case
        assert t > 0

        # 1. Figure out if the current position was stay or change
        # Frame-wise score of stay vs change
        p_stay = emission[t - 1, blank_id]
        p_change = emission[t - 1, tokens[j]]

        # Context-aware score for stay vs change
        stayed = trellis[t - 1, j] + p_stay
        changed = trellis[t - 1, j - 1] + p_change

        # Update position
        t -= 1
        if changed > stayed:
            j -= 1

        # Store the path with frame-wise probability.
        prob = (p_change if changed > stayed else p_stay).exp().item()
        path.append(Point(j, t, prob))

    # Now j == 0, which means, it reached the SoS.
    # Fill up the rest for the sake of visualization
    while t > 0:
        prob = emission[t - 1, blank_id].exp().item()
        path.append(Point(j, t - 1, prob))
        t -= 1

    return path[::-1]


path = backtrack(trellis, emission, tokens)
for p in path:
    print(p)
# Out:
# Point(token_index=0, time_index=0, score=0.9999994039535522)
# Point(token_index=0, time_index=1, score=0.9999994039535522)
# Point(token_index=0, time_index=2, score=0.9999992847442627)
# Point(token_index=0, time_index=3, score=0.9999991655349731)
# Point(token_index=0, time_index=4, score=0.9999992847442627)
# Point(token_index=0, time_index=5, score=0.9999966621398926)
# Point(token_index=0, time_index=6, score=0.99991774559021)
# Point(token_index=0, time_index=7, score=0.9999459981918335)
# Point(token_index=0, time_index=8, score=0.9999610185623169)
# Point(token_index=0, time_index=9, score=0.9999727010726929)
# Point(token_index=0, time_index=10, score=0.9996335506439209)
# Point(token_index=0, time_index=11, score=0.99925297498703)
# Point(token_index=1, time_index=12, score=0.005777979269623756)
# Point(token_index=1, time_index=13, score=0.9999399185180664)
# Point(token_index=2, time_index=14, score=0.8665955066680908)
# Point(token_index=2, time_index=15, score=0.9999997615814209)
# Point(token_index=2, time_index=16, score=0.9999980926513672)
# Point(token_index=2, time_index=17, score=0.9999971389770508)
# Point(token_index=3, time_index=18, score=0.9999960660934448)
# Point(token_index=3, time_index=19, score=0.9999847412109375)
# Point(token_index=3, time_index=20, score=0.9999822378158569)
# Point(token_index=3, time_index=21, score=0.9999963045120239)
# Point(token_index=3, time_index=22, score=0.9999984502792358)
# Point(token_index=3, time_index=23, score=0.9999994039535522)
# Point(token_index=3, time_index=24, score=0.99994957447052)
# Point(token_index=3, time_index=25, score=0.9997625946998596)
# Point(token_index=4, time_index=26, score=0.9972309470176697)
# Point(token_index=5, time_index=27, score=0.5132227540016174)
# Point(token_index=5, time_index=28, score=0.9999905824661255)
# Point(token_index=5, time_index=29, score=0.9999971389770508)
# Point(token_index=5, time_index=30, score=0.9999250173568726)
# Point(token_index=5, time_index=31, score=0.9999480247497559)
# Point(token_index=6, time_index=32, score=0.9905439019203186)
# Point(token_index=6, time_index=33, score=0.9999793767929077)
# Point(token_index=6, time_index=34, score=0.9999855756759644)
# Point(token_index=6, time_index=35, score=0.999984622001648)
# Point(token_index=6, time_index=36, score=0.9999805688858032)
# Point(token_index=6, time_index=37, score=0.8163976073265076)
# Point(token_index=6, time_index=38, score=0.999864935874939)
# Point(token_index=7, time_index=39, score=0.0035111603792756796)
# Point(token_index=7, time_index=40, score=0.1792634129524231)
# Point(token_index=7, time_index=41, score=0.999806821346283)
# Point(token_index=8, time_index=42, score=0.9992817044258118)
# Point(token_index=8, time_index=43, score=0.9993676543235779)
# Point(token_index=8, time_index=44, score=0.0023687926586717367)
# Point(token_index=8, time_index=45, score=0.999980092048645)
# Point(token_index=9, time_index=46, score=0.141757994890213)
# Point(token_index=9, time_index=47, score=0.9999841451644897)
# Point(token_index=9, time_index=48, score=0.999958872795105)
# Point(token_index=10, time_index=49, score=0.9998001456260681)
# Point(token_index=11, time_index=50, score=0.04648418724536896)
# Point(token_index=11, time_index=51, score=2.471293214512116e-07)
# Point(token_index=11, time_index=52, score=0.9997339844703674)
# Point(token_index=12, time_index=53, score=4.33175046055112e-06)
# Point(token_index=13, time_index=54, score=0.00020836242765653878)
# Point(token_index=14, time_index=55, score=8.747947788378951e-08)
# Point(token_index=14, time_index=56, score=0.00018068173085339367)
# Point(token_index=14, time_index=57, score=0.9999910593032837)
# Point(token_index=14, time_index=58, score=0.9999407529830933)
# Point(token_index=14, time_index=59, score=0.00013090981519781053)
# Point(token_index=14, time_index=60, score=0.9996711015701294)
# Point(token_index=14, time_index=61, score=0.9997106194496155)
# Point(token_index=14, time_index=62, score=0.9997450709342957)
# Point(token_index=14, time_index=63, score=0.9999052286148071)
# Point(token_index=14, time_index=64, score=0.9999760389328003)
# Point(token_index=14, time_index=65, score=0.9999934434890747)
# Point(token_index=14, time_index=66, score=0.9999972581863403)
# Point(token_index=14, time_index=67, score=0.9999985694885254)
# Point(token_index=14, time_index=68, score=0.21132491528987885)
# Point(token_index=14, time_index=69, score=0.002608285052701831)
# Point(token_index=14, time_index=70, score=0.9991418123245239)
# Point(token_index=14, time_index=71, score=0.9995744824409485)
# Point(token_index=14, time_index=72, score=0.9997431635856628)
# Point(token_index=14, time_index=73, score=0.9998800754547119)
# Point(token_index=14, time_index=74, score=0.9998723268508911)
# Point(token_index=14, time_index=75, score=0.9917609691619873)
# Point(token_index=14, time_index=76, score=0.9997619986534119)
# Point(token_index=15, time_index=77, score=0.00013925498933531344)
# Point(token_index=15, time_index=78, score=0.999229907989502)
# Point(token_index=15, time_index=79, score=0.9999533891677856)
# Point(token_index=15, time_index=80, score=0.9999494552612305)
# Point(token_index=15, time_index=81, score=0.9999603033065796)
# Point(token_index=15, time_index=82, score=0.9999681711196899)
# Point(token_index=15, time_index=83, score=0.9999129772186279)
# Point(token_index=15, time_index=84, score=0.9982631802558899)
# Point(token_index=16, time_index=85, score=0.007330626714974642)
# Point(token_index=16, time_index=86, score=0.9955515265464783)
# Point(token_index=17, time_index=87, score=0.5858904123306274)
# Point(token_index=17, time_index=88, score=0.9985471367835999)
# Point(token_index=17, time_index=89, score=0.7141315340995789)
# Point(token_index=17, time_index=90, score=0.9604398012161255)
# Point(token_index=18, time_index=91, score=0.9949498176574707)
# Point(token_index=18, time_index=92, score=0.988415002822876)
# Point(token_index=18, time_index=93, score=0.9946212768554688)
# Point(token_index=18, time_index=94, score=0.9986709356307983)
# Point(token_index=18, time_index=95, score=0.9994741082191467)
# Point(token_index=18, time_index=96, score=0.9989172220230103)
# Point(token_index=18, time_index=97, score=0.9968722462654114)
# Point(token_index=18, time_index=98, score=0.038254447281360626)
# Point(token_index=18, time_index=99, score=0.773503839969635)
# Point(token_index=18, time_index=100, score=0.9535174369812012)
# Point(token_index=18, time_index=101, score=0.8700056672096252)
# Point(token_index=18, time_index=102, score=0.914352297782898)
# Point(token_index=18, time_index=103, score=0.9521926641464233)
# Point(token_index=18, time_index=104, score=0.9649224281311035)
# Point(token_index=18, time_index=105, score=0.9721024036407471)
# Point(token_index=18, time_index=106, score=0.9478405714035034)
# Point(token_index=18, time_index=107, score=0.5004900097846985)
# Point(token_index=18, time_index=108, score=0.7160098552703857)
# Point(token_index=18, time_index=109, score=0.997816801071167)
# Point(token_index=18, time_index=110, score=0.1552780419588089)
# Point(token_index=18, time_index=111, score=0.4944460391998291)
# Point(token_index=18, time_index=112, score=0.8398309946060181)
# Point(token_index=19, time_index=113, score=0.3395923972129822)
# Point(token_index=19, time_index=114, score=0.38449522852897644)
# Point(token_index=20, time_index=115, score=0.7968072891235352)
# Point(token_index=20, time_index=116, score=0.9878701567649841)
# Point(token_index=20, time_index=117, score=0.9980717897415161)
# Point(token_index=20, time_index=118, score=0.9990848302841187)
# Point(token_index=20, time_index=119, score=0.9994187355041504)
# Point(token_index=20, time_index=120, score=0.9995145797729492)
# Point(token_index=20, time_index=121, score=0.9995495676994324)
# Point(token_index=20, time_index=122, score=0.9995538592338562)
# Point(token_index=20, time_index=123, score=0.9994218349456787)
# Point(token_index=20, time_index=124, score=0.9993913173675537)
# Point(token_index=20, time_index=125, score=0.9996343851089478)
# Point(token_index=20, time_index=126, score=0.9991944432258606)
# Point(token_index=20, time_index=127, score=0.03577093407511711)
# Point(token_index=20, time_index=128, score=0.9775030016899109)
# Point(token_index=20, time_index=129, score=0.9950160384178162)
# Point(token_index=20, time_index=130, score=0.9979475140571594)
# Point(token_index=20, time_index=131, score=0.9995662569999695)
# Point(token_index=20, time_index=132, score=0.9998501539230347)
# Point(token_index=20, time_index=133, score=0.999885082244873)
# Point(token_index=20, time_index=134, score=0.9998852014541626)
# Point(token_index=20, time_index=135, score=0.9999140501022339)
# Point(token_index=20, time_index=136, score=0.9998487234115601)
# Point(token_index=20, time_index=137, score=0.20243936777114868)
# Point(token_index=20, time_index=138, score=0.9950994849205017)
# Point(token_index=20, time_index=139, score=0.8987180590629578)
# Point(token_index=20, time_index=140, score=0.057875487953424454)
# Point(token_index=21, time_index=141, score=0.7788476347923279)
# Point(token_index=21, time_index=142, score=0.9895998239517212)
# Point(token_index=21, time_index=143, score=0.9942398071289062)
# Point(token_index=21, time_index=144, score=0.036636702716350555)
# Point(token_index=21, time_index=145, score=0.9986658096313477)
# Point(token_index=22, time_index=146, score=0.6757277846336365)
# Point(token_index=22, time_index=147, score=0.9999934434890747)
# Point(token_index=22, time_index=148, score=0.9999943971633911)
# Point(token_index=22, time_index=149, score=0.9999969005584717)
# Point(token_index=22, time_index=150, score=0.9999978542327881)
# Point(token_index=22, time_index=151, score=0.9999983310699463)
# Point(token_index=22, time_index=152, score=0.9999986886978149)
# Point(token_index=22, time_index=153, score=0.999998927116394)
# Point(token_index=22, time_index=154, score=0.999998927116394)
# Point(token_index=22, time_index=155, score=0.9999990463256836)
# Point(token_index=22, time_index=156, score=0.9999990463256836)
# Point(token_index=22, time_index=157, score=0.9999990463256836)
# Point(token_index=22, time_index=158, score=0.9999992847442627)
# Point(token_index=22, time_index=159, score=0.9999991655349731)
# Point(token_index=22, time_index=160, score=0.9999991655349731)
# Point(token_index=22, time_index=161, score=0.9999991655349731)
# Point(token_index=22, time_index=162, score=0.9999992847442627)
# Point(token_index=22, time_index=163, score=0.9999990463256836)
# Point(token_index=22, time_index=164, score=0.999997615814209)
# Point(token_index=22, time_index=165, score=0.999997615814209)
# Point(token_index=22, time_index=166, score=0.999997615814209)
# Point(token_index=22, time_index=167, score=0.999997615814209)
# Point(token_index=22, time_index=168, score=0.999997615814209)
# Point(token_index=22, time_index=169, score=0.999997615814209)
# Point(token_index=22, time_index=170, score=0.999997615814209)
# Point(token_index=22, time_index=171, score=0.999997615814209)
# Point(token_index=22, time_index=172, score=0.999997615814209)
# Point(token_index=22, time_index=173, score=0.999997615814209)
# Point(token_index=22, time_index=174, score=0.999997615814209)
# Point(token_index=22, time_index=175, score=0.999997615814209)
# Point(token_index=22, time_index=176, score=0.999997615814209)
# Point(token_index=22, time_index=177, score=0.999997615814209)
# Point(token_index=22, time_index=178, score=0.999997615814209)
# Point(token_index=22, time_index=179, score=0.9999988079071045)
# Point(token_index=22, time_index=180, score=0.999998927116394)
# Point(token_index=22, time_index=181, score=0.9999985694885254)
# Point(token_index=22, time_index=182, score=0.9999983310699463)

# %% [markdown]
# ### Visualization

# %%
def plot_trellis_with_path(trellis, path):
    # To plot trellis with path, we take advantage of 'nan' value
    trellis_with_path = trellis.clone()
    for _, p in enumerate(path):
        trellis_with_path[p.time_index, p.token_index] = float("nan")
    plt.imshow(trellis_with_path.T, origin="lower")
    plt.title("The path found by backtracking")
    plt.tight_layout()


plot_trellis_with_path(trellis, path)

# %% [markdown]
# Looking good.

# %% [markdown]
# ## Segment the path
# Now this path contains repetations for the same labels, so
# let’s merge them to make it close to the original transcript.
#
# When merging the multiple path points, we simply take the average
# probability for the merged segments.

# %%
# Merge the labels
@dataclass
class Segment:
    label: str
    start: int
    end: int
    score: float

    def __repr__(self):
        return f"{self.label}\t({self.score:4.2f}): [{self.start:5d}, {self.end:5d})"

    @property
    def length(self):
        return self.end - self.start


def merge_repeats(path):
    i1, i2 = 0, 0
    segments = []
    while i1 < len(path):
        while i2 < len(path) and path[i1].token_index == path[i2].token_index:
            i2 += 1
        score = sum(path[k].score for k in range(i1, i2)) / (i2 - i1)
        segments.append(
            Segment(
                transcript[path[i1].token_index],
                path[i1].time_index,
                path[i2 - 1].time_index + 1,
                score,
            )
        )
        i1 = i2
    return segments


segments = merge_repeats(path)
for seg in segments:
    print(seg)
# Out:
# |	(1.00): [    0,    12)
# A	(0.50): [   12,    14)
# |	(0.97): [   14,    18)
# B	(1.00): [   18,    26)
# O	(1.00): [   26,    27)
# T	(0.90): [   27,    32)
# T	(0.97): [   32,    39)
# L	(0.39): [   39,    42)
# E	(0.75): [   42,    46)
# |	(0.71): [   46,    49)
# O	(1.00): [   49,    50)
# F	(0.35): [   50,    53)
# |	(0.00): [   53,    54)
# W	(0.00): [   54,    55)
# A	(0.78): [   55,    77)
# T	(0.87): [   77,    85)
# E	(0.50): [   85,    87)
# R	(0.81): [   87,    91)
# |	(0.82): [   91,   113)
# H	(0.36): [  113,   115)
# |	(0.88): [  115,   141)
# H	(0.76): [  141,   146)
# |	(0.99): [  146,   183)

# %% [markdown]
# ### Visualization

# %%
def plot_trellis_with_segments(trellis, segments, transcript):
    # To plot trellis with path, we take advantage of 'nan' value
    trellis_with_path = trellis.clone()
    for i, seg in enumerate(segments):
        if seg.label != "|":
            trellis_with_path[seg.start : seg.end, i] = float("nan")

    fig, [ax1, ax2] = plt.subplots(2, 1, sharex=True)
    ax1.set_title("Path, label and probability for each label")
    ax1.imshow(trellis_with_path.T, origin="lower", aspect="auto")

    for i, seg in enumerate(segments):
        if seg.label != "|":
            ax1.annotate(seg.label, (seg.start, i - 0.7), size="small")
            ax1.annotate(f"{seg.score:.2f}", (seg.start, i + 3), size="small")

    ax2.set_title("Label probability with and without repetation")
    xs, hs, ws = [], [], []
    for seg in segments:
        if seg.label != "|":
            xs.append((seg.end + seg.start) / 2 + 0.4)
            hs.append(seg.score)
            ws.append(seg.end - seg.start)
            ax2.annotate(seg.label, (seg.start + 0.8, -0.07))
    ax2.bar(xs, hs, width=ws, color="gray", alpha=0.5, edgecolor="black")

    xs, hs = [], []
    for p in path:
        label = transcript[p.token_index]
        if label != "|":
            xs.append(p.time_index + 1)
            hs.append(p.score)

    ax2.bar(xs, hs, width=0.5, alpha=0.5)
    ax2.axhline(0, color="black")
    ax2.grid(True, axis="y")
    ax2.set_ylim(-0.1, 1.1)
    fig.tight_layout()


plot_trellis_with_segments(trellis, segments, transcript)

# %% [markdown]
# Looks good.

# %% [markdown]
# ## Merge the segments into words
# Now let’s merge the words. The Wav2Vec2 model uses ``'|'``
# as the word boundary, so we merge the segments before each occurance of
# ``'|'``.
#
# Then, finally, we segment the original audio into segmented audio and
# listen to them to see if the segmentation is correct.

# %%
# Merge words
def merge_words(segments, separator="|"):
    words = []
    i1, i2 = 0, 0
    while i1 < len(segments):
        if i2 >= len(segments) or segments[i2].label == separator:
            if i1 != i2:
                segs = segments[i1:i2]
                word = "".join([seg.label for seg in segs])
                score = sum(seg.score * seg.length for seg in segs) / sum(seg.length for seg in segs)
                words.append(Segment(word, segments[i1].start, segments[i2 - 1].end, score))
            i1 = i2 + 1
            i2 = i1
        else:
            i2 += 1
    return words


word_segments = merge_words(segments)
for word in word_segments:
    print(word)
# Out:
# A	(0.50): [   12,    14)
# BOTTLE	(0.88): [   18,    46)
# OF	(0.51): [   49,    53)
# WATER	(0.77): [   54,    91)
# H	(0.36): [  113,   115)
# H	(0.76): [  141,   146)

# %% [markdown]
# ### Visualization

# %%
def plot_alignments(trellis, segments, word_segments, waveform, sample_rate=bundle.sample_rate):
    trellis_with_path = trellis.clone()
    for i, seg in enumerate(segments):
        if seg.label != "|":
            trellis_with_path[seg.start : seg.end, i] = float("nan")

    fig, [ax1, ax2] = plt.subplots(2, 1)

    ax1.imshow(trellis_with_path.T, origin="lower", aspect="auto")
    ax1.set_facecolor("lightgray")
    ax1.set_xticks([])
    ax1.set_yticks([])

    for word in word_segments:
        ax1.axvspan(word.start - 0.5, word.end - 0.5, edgecolor="white", facecolor="none")

    for i, seg in enumerate(segments):
        if seg.label != "|":
            ax1.annotate(seg.label, (seg.start, i - 0.7), size="small")
            ax1.annotate(f"{seg.score:.2f}", (seg.start, i + 3), size="small")

    # The original waveform
    ratio = waveform.size(0) / sample_rate / trellis.size(0)
    ax2.specgram(waveform, Fs=sample_rate)
    for word in word_segments:
        x0 = ratio * word.start
        x1 = ratio * word.end
        ax2.axvspan(x0, x1, facecolor="none", edgecolor="white", hatch="/")
        ax2.annotate(f"{word.score:.2f}", (x0, sample_rate * 0.51), annotation_clip=False)

    for seg in segments:
        if seg.label != "|":
            ax2.annotate(seg.label, (seg.start * ratio, sample_rate * 0.55), annotation_clip=False)
    ax2.set_xlabel("time [second]")
    ax2.set_yticks([])
    fig.tight_layout()


plot_alignments(
    trellis,
    segments,
    word_segments,
    waveform[0],
)
# Out:
# e:\anacon2\envs\mypyt\Lib\site-packages\matplotlib\axes\_axes.py:8089: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# ## Audio Samples

# %%
def display_segment(i):
    ratio = waveform.size(1) / trellis.size(0)
    word = word_segments[i]
    x0 = int(ratio * word.start)
    x1 = int(ratio * word.end)
    print(f"{word.label} ({word.score:.2f}): {x0 / bundle.sample_rate:.3f} - {x1 / bundle.sample_rate:.3f} sec")
    segment = waveform[:, x0:x1]
    return IPython.display.Audio(segment.numpy(), rate=bundle.sample_rate)

# %%
# Generate the audio for each segment
print(transcript)
IPython.display.Audio(SPEECH_FILE)
# Out:
# |A|BOTTLE|OF|WATER|H|H|
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(0)
# Out:
# A (0.50): 0.241 - 0.281 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(1)
# Out:
# BOTTLE (0.88): 0.361 - 0.923 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(2)
# Out:
# OF (0.51): 0.983 - 1.063 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(3)
# Out:
# WATER (0.77): 1.083 - 1.826 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(4)
# Out:
# H (0.36): 2.267 - 2.308 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(5)
# Out:
# H (0.76): 2.829 - 2.930 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
