# %%
import pandas as pd

# Read the TSV file
df = pd.read_csv('E:/project_summer/data/cv-corpus-16.1-delta-2023-12-06-en/cv-corpus-16.1-delta-2023-12-06/en/validated.tsv', sep='\t')

# Save the DataFrame as a CSV file
df.to_csv('E:/project_summer/data/validated_csv/validated_csv', index=False)

# %%
df=df.drop(columns=['client_id','up_votes', 'down_votes', 'variant','path','segment','locale'])

# %%
df
# Out:
#                                                sentence       age  gender  \
# 0     These locomotives are serviced at Washwood Heath.       NaN     NaN
# 1     Here, she turned her inspirations towards writ...       NaN     NaN
# 2          There is also a garnet mine in West Redding.       NaN     NaN
# 3     They hastily drive to the plane, and flee from...       NaN     NaN
# 4       They found one such edge in Fairbairn's system.       NaN     NaN
# ...                                                 ...       ...     ...
# 3403  She seems to have played little part in politics.  twenties  female
# 3404             He made his film debut from movie Uma.  twenties  female
# 3405  There are no known remaining records of the fi...  twenties  female
# 3406             They can be described as medium-sized.  twenties  female
# 3407          The use of the sample remains uncredited.  twenties  female
#
#                                                 accents
# ...

# %%
df= df[df['accents'] != 'Unknown']

# %%
# df_filtered

# %%
df.isnull().count()
# Out:
# sentence    3408
# age         3408
# gender      3408
# accents     3408
# dtype: int64

# %%
# import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the TSV file
# df = pd.read_csv('path/to/your/file.tsv', sep='\t')

# Display basic statistics and info
df = df.dropna()
print(df.info())
print(df.describe())

# Handle NaN values if necessary
df['age'] = df['age'].fillna('Unknown')
df['gender'] = df['gender'].fillna('Unknown')
df['accents'] = df['accents'].fillna('Unknown')

# Up votes distribution

# Down votes distribution

# Age distribution (if numeric data is available)
if df['age'].dtype != 'object':
    plt.figure(figsize=(10, 6))
    sns.histplot(df['age'], bins=30, kde=True)
    plt.title('Distribution of Age')
    plt.xlabel('Age')
    plt.ylabel('Frequency')
    plt.show()

# Gender distribution
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='gender', order=df['gender'].value_counts().index)
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()

# Accents distribution
plt.figure(figsize=(10, 12))
sns.countplot(data=df, y='accents', order=df['accents'].value_counts().index)
plt.title('Distribution of Accents')
plt.xlabel('Frequency')
plt.ylabel('Accents')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2999 entries, 5 to 3407
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  2999 non-null   object
#  1   age       2999 non-null   object
#  2   gender    2999 non-null   object
#  3   accents   2999 non-null   object
# dtypes: object(4)
# memory usage: 117.1+ KB
# None
#                                   sentence       age  gender  \
# count                                 2999      2999    2999
# unique                                2999         7       3
# top     Flatow was given a co-star credit.  twenties  female
# freq                                     1      1559    1477
#
#                                                   accents
# count                                                2999
# unique                                                 44
# top     Southern African (South Africa, Zimbabwe, Nami...
# ...

# %%
df["accents"].unique()
# Out:
# array(['United States English', 'Canadian English', 'England English',
#        'India and South Asia (India, Pakistan, Sri Lanka)',
#        'Australian English', 'Russian English',
#        'not native English, originally French native language',
#        'India and South Asia (India, Pakistan, Sri Lanka),England English,Southern African (South Africa, Zimbabwe, Namibia)',
#        'England English,United States English',
#        'United States English,Oregonian ,West Coast,generic white guy ',
#        'Domincian', 'Filipino,Canadian English',
#        'United States English,Ponglish',
#        'English Cumbrian,English Northern', 'Strong Russian accent',
#        'Midatlantic',
#        'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)',
#        'Cowdengelly,Scottish English', 'Nigerian English',
#        'United States English,Pacific Northwest English',
#        'Personal idiolect', 'Finnish',
#        'England English,Received Pronunciation',
# ...

# %%
# United States English', 'Canadian English', 'German English',
#        'England English'
# Out:
#   Cell In[24], line 1
#     United States English', 'Canadian English', 'German English',
#                                                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import pandas as pd

# Read the TSV file
# df = pd.read_csv('path/to/your/file.tsv', sep='\t')

# Filter rows where 'accents' column has 'United States' or 'England'
df_filtered = df[df['accents'].isin(['United States English', 'Canadian English'])]

# Display the filtered DataFrame
# print(df_filtered.info())
# print(df_filtered.head())

# Save the filtered DataFrame as a new CSV file if needed
# df_filtered.to_csv('path/to/save/filtered_file.csv', index=False)
df_filtered
# Out:
#                                                sentence       age gender  \
# 5                    Flatow was given a co-star credit.  twenties   male
# 8           A timetable for the move was not specified.   fifties   male
# 25    The character of the Well-Manicured Man has be...  twenties   male
# 41    Band In The Rain is also from the Barcelona show.  twenties   male
# 45    He joined the United States Air Force straight...     teens   male
# ...                                                 ...       ...    ...
# 2860  He discovers the cloned house and breaks in as...  thirties   male
# 2861                          It has since been ruined.  thirties   male
# 2862  Residents, however, generally continue to refe...  thirties   male
# 2863  There were six original books planned, but the...  thirties   male
# 2864  This and its surroundings are very rich in flo...  thirties   male
#
#                     accents
# 5     United States English
# 8          Canadian English
# ...

# %%
    plt.figure(figsize=(10, 6))
    sns.histplot(df_filtered ['age'], bins=10, kde=True)
    plt.title('Distribution of Age')
    plt.xlabel('Age')
    plt.ylabel('Frequency')
    plt.show()

# %%
df = pd.read_csv('E:/project_summer/data/cv-corpus-16.1-delta-2023-12-06-en/cv-corpus-16.1-delta-2023-12-06/en/validated.tsv', sep='\t')
df= df[df['accents'] != 'Unknown']
df=df.drop(columns=['up_votes', 'down_votes', 'variant','segment'])
df = df.dropna()

# %%
df
# Out:
#                                               client_id  \
# 5     059e6e48ab8e9659233a4e32dbeadfbdd0c240e923977d...
# 8     0b6c489384d032332115dd70c9033e5436849eba2feb5d...
# 25    1da998f354109f83fcae4f360e0e08ad0e64937a7870c9...
# 29    22ee2837aa6fc4bbe17229c02ae78bab0a4200ae6541a9...
# 34    2748d63cf445bf16aaaa8926ff10eaa7f0110525b499d9...
# ...                                                 ...
# 3403  cf166b2a376b2518887f5a2e3c347a69f495260309ac27...
# 3404  cf166b2a376b2518887f5a2e3c347a69f495260309ac27...
# 3405  cf166b2a376b2518887f5a2e3c347a69f495260309ac27...
# 3406  cf166b2a376b2518887f5a2e3c347a69f495260309ac27...
# 3407  cf166b2a376b2518887f5a2e3c347a69f495260309ac27...
#
#                               path  \
# 5     common_voice_en_38570599.mp3
# 8     common_voice_en_39572424.mp3
# 25    common_voice_en_38523203.mp3
# 29    common_voice_en_39561365.mp3
# 34    common_voice_en_38524458.mp3
# ...                            ...
# 3403  common_voice_en_38852923.mp3
# ...

# %%
df.to_csv('E:/project_summer/data/validated_csv/validated_csv_USA_CANADA', index=False)
